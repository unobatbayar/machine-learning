# %%
pip install scikit-learn pandas numpy matplotlib seaborn kagglehub

# %%
# Import the libraries: First, import the necessary libraries.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Load the Dataset: We can load the Iris dataset directly from scikit-learn.

import kagglehub

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target labels (species)

# %%
# Explore the Dataset: Check out the basic structure and features of the dataset.

# Convert to DataFrame for easy exploration
df = pd.DataFrame(X, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(y, iris.target_names)

# Display the first few rows
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2  \
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# 4. Split the Dataset into Training and Testing Sets: Split the dataset into a training set (to train the model) and a test set (to evaluate the model).

# %%
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# 5. Data Preprocessing (Scaling): It's a good practice to standardize the features, especially for distance-based algorithms like KNN.

# %%
# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# 6. Train a K-Nearest Neighbors (KNN) Classifier: We'll use a simple KNN model for classification.

# %%
# Initialize the KNN classifier
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# 7. Make Predictions: Use the trained model to predict the test data.

# %%
# Predict the target for the test set
y_pred = knn.predict(X_test_scaled)

# %% [markdown]
# 8. Evaluate the Model: Check the accuracy and confusion matrix to evaluate how well the model is performing.

# %%
# Accuracy score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 1.00

# %%
# You can use pairplot to visualize relationships between features
sns.pairplot(df, hue="species", palette="Set2")
plt.show()

# %% [markdown]
# Key Concepts in This Project:
#
# Dataset Loading: How to load and explore a dataset.
# Data Splitting: How to split data into training and testing sets.
# Data Preprocessing: Standardizing or scaling data.
# Model Training: Training a machine learning model (KNN in this case).
# Model Evaluation: Measuring the model’s performance using accuracy and confusion matrix.
# Visualization: Using seaborn for data visualization.
#
# What Next?
# Once you're comfortable with this, you can explore:
#
# Trying other classifiers like Decision Trees, Logistic Regression, or SVM.
# Tuning the model using techniques like cross-validation or hyperparameter tuning.
# Trying different datasets on Kaggle and solving more complex problems.
# This should give you a good start with machine learning in Python. Let me know if you have any questions or need further guidance!
